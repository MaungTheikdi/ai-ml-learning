# %%
import numpy as np
import pandas as pd

sales = {
    "month": ["Jan", "Feb", "Mar", "Apr", "May"],
    "sales": [
        12000000,
        14500000,
        16200000,
        15800000,
        18100000
    ]
}

df = pd.DataFrame(sales)

print(df)
print(df["sales"].mean())
print(df["sales"].sum())

print(df["sales"].max())
print(df["sales"].min())
# Out:
#   month     sales
# 0   Jan  12000000
# 1   Feb  14500000
# 2   Mar  16200000
# 3   Apr  15800000
# 4   May  18100000
# 15320000.0
# 76600000
# 18100000
# 12000000
